# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('mushroom.csv')
print(df.shape)
df.head()
# Out:
# (2000, 26)
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
df['class'].value_counts()
# Out:
# class
# poisonous    1400
# edible        600
# Name: count, dtype: int64

# %%
#from the above value counts we got to know that poisionous data have 1400 and edible column has 600 , which is imbalnce in data

# %%
sns.countplot(data=df,x='class',orient='h',stat='count')
plt.show()

# %%
df['class'] = df['class'].replace({'edible':1,'poisonous':0})
df.head()
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
target = df['class']
target.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
np.unique(df['class'])
# Out:
# array([0, 1], dtype=int64)

# %%
features = df.drop(['class','Unnamed: 0'],axis=1)
features
# Out:
#      cap_shape cap_surface cap_color bruises     odor gill_attachment  \
# 0       sunken       scaly     white      no    anise      descending
# 1       sunken     fibrous       red      no    anise         notched
# 2         flat     grooves    purple     yes     foul      descending
# 3         bell       scaly      pink     yes    fishy         notched
# 4         flat      smooth    yellow     yes    musty            free
# ...        ...         ...       ...     ...      ...             ...
# 1995    sunken       scaly     brown     yes     foul        attached
# 1996    sunken       scaly    purple     yes    musty        attached
# 1997    convex     grooves     green     yes    fishy         notched
# 1998      bell      smooth     white      no  pungent            free
# 1999    convex       scaly    yellow     yes  pungent      descending
#
#      gill_spacing gill_size gill_color stalk_shape  ...  \
# 0         distant     broad       pink    tapering  ...
# ...

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap_shape                 2000 non-null   object
#  1   cap_surface               2000 non-null   object
#  2   cap_color                 2000 non-null   object
#  3   bruises                   2000 non-null   object
#  4   odor                      2000 non-null   object
#  5   gill_attachment           2000 non-null   object
#  6   gill_spacing              2000 non-null   object
#  7   gill_size                 2000 non-null   object
#  8   gill_color                2000 non-null   object
#  9   stalk_shape               2000 non-null   object
#  10  stalk_root                2000 non-null   object
#  11  stalk_surface_above_ring  2000 non-null   object
#  12  stalk_surface_below_ring  2000 non-null   object
# ...

# %%
categorical_columns = features.select_dtypes(include=['object']).columns.tolist()
categorical_columns
# Out:
# ['cap_shape',
#  'cap_surface',
#  'cap_color',
#  'bruises',
#  'odor',
#  'gill_attachment',
#  'gill_spacing',
#  'gill_size',
#  'gill_color',
#  'stalk_shape',
#  'stalk_root',
#  'stalk_surface_above_ring',
#  'stalk_surface_below_ring',
#  'stalk_color_above_ring',
#  'stalk_color_below_ring',
#  'veil_type',
#  'veil_color',
#  'ring_number',
#  'ring_type',
#  'spore_print_color',
#  'population',
#  'habitat']

# %%
from sklearn import preprocessing
columns = categorical_columns # columns names where transform is required
for X in columns:
    exec(f'le_{X} = preprocessing.LabelEncoder()')  #create label encoder with name "le_X", where X is column name
    exec(f'features.{X} = le_{X}.fit_transform(df.{X})')  #execute fit transform for column X with respective lable encoder "le_X", where X is column name
features.head()  # to display transformed results
# Out:
#    cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0          4            2          7        0     1                1
# 1          4            0          6        0     1                3
# 2          3            1          5        1     4                1
# 3          0            2          4        1     3                3
# 4          3            3          8        1     5                2
#
#    gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# 0             2          0           7            1  ...
# 1             1          1           3            0  ...
# 2             1          0           8            1  ...
# 3             0          0           6            0  ...
# 4             1          1           6            0  ...
#
#    stalk_color_below_ring  veil_type  veil_color  ring_number  ring_type  \
# 0                       8          0           0            2          6
# ...

# %%
features.hist(grid=False)
plt.plot()
# Out:
# []

# %%
features
# Out:
#       cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0             4            2          7        0     1                1
# 1             4            0          6        0     1                3
# 2             3            1          5        1     4                1
# 3             0            2          4        1     3                3
# 4             3            3          8        1     5                2
# ...         ...          ...        ...      ...   ...              ...
# 1995          4            2          0        1     4                0
# 1996          4            2          5        1     5                0
# 1997          2            1          3        1     3                3
# 1998          0            3          7        0     7                2
# 1999          2            2          8        1     7                1
#
#       gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# ...

# %%
sns.distplot(features)
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler
stdscal = StandardScaler()

# %%
features1 = stdscal.fit_transform(features)

# %%
features_new=pd.DataFrame(features1,columns=features.columns)
features_new
# Out:
#       cap_shape  cap_surface  cap_color   bruises      odor  gill_attachment  \
# 0      1.356643     0.398424   1.194966 -1.023271 -1.175776        -0.498601
# 1      1.356643    -1.396280   0.814161 -1.023271 -1.175776         1.277359
# 2      0.660035    -0.498928   0.433356  0.977259  0.004524        -0.498601
# 3     -1.429786     0.398424   0.052551  0.977259 -0.388909         1.277359
# 4      0.660035     1.295777   1.575772  0.977259  0.397958         0.389379
# ...         ...          ...        ...       ...       ...              ...
# 1995   1.356643     0.398424  -1.470669  0.977259  0.004524        -1.386580
# 1996   1.356643     0.398424   0.433356  0.977259  0.397958        -1.386580
# 1997  -0.036572    -0.498928  -0.328254  0.977259 -0.388909         1.277359
# 1998  -1.429786     1.295777   1.194966 -1.023271  1.184825         0.389379
# 1999  -0.036572     0.398424   1.575772  0.977259  1.184825        -0.498601
#
# ...

# %%
sns.distplot(features_new)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## import the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
x_train,x_test,y_train,y_test = train_test_split(features,target,random_state=100,train_size=0.8)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1600, 24)
# (400, 24)
# (1600,)
# (400,)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(C=1.0,kernel='rbf',gamma=0.3)

# %%
svc.fit(x_train,y_train)
# Out:
# SVC(gamma=0.3)

# %%
ypred = svc.predict(x_test)

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.8575

# %%
#we got 85% of accuracy from the randomly given samples C=1.0,kernal='rbf',gamma=0.3

# %%
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       256
#            1       1.00      0.60      0.75       144
#
#     accuracy                           0.86       400
#    macro avg       0.91      0.80      0.83       400
# weighted avg       0.88      0.86      0.85       400

# %%
#f1 score = eatable = 75% and poisionous = 90 as we have more no.of datas are poisiouns

# %%
#lets see the gridsearch params to get the best params and check the model performance
from sklearn.model_selection import GridSearchCV
params = {'C':[1,2,3,4],'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'gamma':[0.1,0.2,0.3,0.4]}

# %%
grid = GridSearchCV(svc,params,verbose=2)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 1.0min
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time= 1.2min
